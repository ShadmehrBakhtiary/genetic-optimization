# %%
import keras
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.models import Model
from keras.models import load_model
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
#load mnist dataset
(X_train_loaded, y_train_loaded), (X_test_loaded, y_test_loaded) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # Preparing the Dataset

# %%
X_train = X_train_loaded.reshape(X_train_loaded.shape[0], 28, 28, 1)
X_test = X_test_loaded.reshape(X_test_loaded.shape[0], 28, 28, 1)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

X_train/=255
X_test/=255

number_of_classes = 10
y_train = keras.utils.to_categorical(y_train_loaded, num_classes=number_of_classes)
y_test = keras.utils.to_categorical(y_test_loaded, num_classes=number_of_classes)

#decreasing dataset to train faster for algorithm testing
X_train, _,_,_,_,_ = np.split(X_train,6)
y_train, _,_,_,_,_ = np.split(y_train,6)
input_shape = X_train[1].shape
print(input_shape)
print(X_train.shape)
# Out:
# (28, 28, 1)
# (10000, 28, 28, 1)

# %%
class Network:
    def __init__(self):
        model = Sequential()
        model.add(Conv2D(24, kernel_size=(3, 3), strides=(1, 1), activation='relu', input_shape=input_shape))
        model.add(Conv2D(32, (3, 3), activation='relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Flatten())
        model.add(Dropout(0.5))
        model.add(Dense(100,activation = "relu"))
        model.add(Dense(10, activation="softmax"))
        model.compile(loss="categorical_crossentropy", optimizer="adam",metrics=['accuracy'])
        self.model = model
        self.acc_history = []

    def return_acc_history(self):
        return self.acc_history

    def get_layer_weight(self,i):
        return self.model.layers[i].get_weights()

    def set_layer_weight(self,i,weight):
        self.model.layers[i].set_weights(weight)

    def train(self):
        self.model.fit(X_train,y_train, batch_size = 32, epochs = 1, verbose = 1,shuffle = True) #, validation_data =(X_test, y_test)

    def test(self):
        loss, acc = self.model.evaluate(X_test,y_test)
        self.acc_history.append(acc)
        return acc

    def load_layer_weights(self,weights):
        self.model.set_weights(weights)

    def give_weights(self):
        return self.model.get_weights()
    def weight_len(self):
        i = 0
        for j in self.model.layers:
            i+=1
        return i
    def architecture(self):
        self.model.summary()

# %%
class GeneticAlgorithm:
    def __init__(self, population_size, mutation_rate, generations = 50):
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.generations = generations
        self.population = None
        self.children_population_weights = []
        self.acces = []
        self.norm_acces = []

    def create_population(self):
        self.population = [Network() for i in range(self.population_size)]

    def train_generation(self):
        for member in self.population:
                member.train()

    def predict(self):
        for member in self.population:
                acc = member.test()
                self.acc.append(acc)
                #logging.info("Losses: {}".format(loss))

    def normalize(self):
        sum_ = sum(self.acc)
        self.norm_acc = [i/sum_ for i in self.acc]
        print("\nNormalization sum: ",sum(self.norm_acc))
        #assert sum(self.norm_acc) == 1

    def show_weights(self):
        for i in parent_weights:
            print(i)
    def clear_losses(self):
        self.norm_acc = []
        self.acc = []

    def mutate(self):
        for member in self.population:
            for i in range(member.weight_len()):
                if np.random.random() < self.mutation_rate:
                    print("\nMutation!")
                    old_weight = member.get_layer_weight(i)
                    new_weight = [np.random.uniform(low=-1, high=1, size=old_weight[i].shape) for i in range(len(old_weight))]
                    member.set_layer_weight(i, new_weight)

    def reproduction(self):
        """
        Reproduction through midpoint crossover method
        """
        population_idx = [i for i in range(len(self.population))]
        for i in range(len(self.population)):
        #selects two parents probabilistic accroding to the fitness
            if sum(self.norm_acc) != 0:
                parent1 = np.random.choice(population_idx, p = self.norm_acc)
                parent2 = np.random.choice(population_idx, p = self.norm_acc)
            else:
              # if there are no "best" parents choose randomly
                parent1 = np.random.choice(population_idx)
                parent2 = np.random.choice(population_idx)

            # picking random midpoint for crossing over name/DNA
            parent1_weights = self.population[parent1].give_weights()
            parent2_weights = self.population[parent2].give_weights()


            mid_point = np.random.choice([i for i in range(len(parent1_weights))])
            # adding DNA-Sequences of the parents to final DNA
            self.children_population_weights.append(parent1_weights[:mid_point] + parent2_weights[mid_point:])
        # old population gets the new and proper weights
        for i in range(len(self.population)):
            for j in range(len(self.children_population_weights)):
                self.population[i].load_layer_weights(self.children_population_weights[j])



    def run_evolution(self):
        for episode in range(self.generations):
            self.clear_losses()
            self.train_generation()
            self.predict()
            if episode != self.generations -1:
                self.normalize()
                self.reproduction()
                self.mutate()
            else:
                pass

        # plotting history:
        for a in range(self.generations):
            for member in self.population:
                plt.plot(member.acc_history)
        plt.xlabel("Generations")
        plt.ylabel("Accuracy")
        plt.show()

# %%
GA = GeneticAlgorithm(population_size = 8,mutation_rate = 0.1, generations = 6)
GA.create_population()
GA.run_evolution()
# Out:
# 313/313 [==============================] - 6s 5ms/step - loss: 0.5547 - accuracy: 0.8245
# 313/313 [==============================] - 3s 5ms/step - loss: 0.5602 - accuracy: 0.8240
# 313/313 [==============================] - 3s 4ms/step - loss: 0.5373 - accuracy: 0.8293
# 313/313 [==============================] - 3s 4ms/step - loss: 0.5980 - accuracy: 0.8079
# 313/313 [==============================] - 2s 4ms/step - loss: 0.5705 - accuracy: 0.8121
# 313/313 [==============================] - 3s 6ms/step - loss: 0.5522 - accuracy: 0.8255
# 313/313 [==============================] - 3s 4ms/step - loss: 0.5281 - accuracy: 0.8393
# 313/313 [==============================] - 3s 4ms/step - loss: 0.5504 - accuracy: 0.8269
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1453 - accuracy: 0.9568
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1487 - accuracy: 0.9586
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1413 - accuracy: 0.9566
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1649 - accuracy: 0.9514
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1478 - accuracy: 0.9583
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1593 - accuracy: 0.9532
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1231 - accuracy: 0.9659
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1423 - accuracy: 0.9606
#
# Normalization sum:  1.0
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
# 313/313 [==============================] - 1s 4ms/step - loss: 1.6974 - accuracy: 0.8014
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1929 - accuracy: 0.9416
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1943 - accuracy: 0.9416
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1942 - accuracy: 0.9396
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5407 - accuracy: 0.8639
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1939 - accuracy: 0.9402
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6068 - accuracy: 0.8560
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4045 - accuracy: 0.8841
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1829 - accuracy: 0.9459
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0955 - accuracy: 0.9724
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1036 - accuracy: 0.9693
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0957 - accuracy: 0.9704
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1267 - accuracy: 0.9651
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0960 - accuracy: 0.9701
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1270 - accuracy: 0.9613
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1175 - accuracy: 0.9649
#
# Normalization sum:  1.0
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4488 - accuracy: 0.8867
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4302 - accuracy: 0.8888
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4215 - accuracy: 0.8940
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4059 - accuracy: 0.8952
# 313/313 [==============================] - 2s 6ms/step - loss: 1.6500 - accuracy: 0.8358
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3865 - accuracy: 0.8994
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4190 - accuracy: 0.8898
# 313/313 [==============================] - 1s 4ms/step - loss: 11.0754 - accuracy: 0.2168
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1355 - accuracy: 0.9602
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1163 - accuracy: 0.9649
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1254 - accuracy: 0.9629
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1244 - accuracy: 0.9641
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1695 - accuracy: 0.9509
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1048 - accuracy: 0.9669
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1200 - accuracy: 0.9623
# 313/313 [==============================] - 1s 3ms/step - loss: 1.8243 - accuracy: 0.4146
#
# Normalization sum:  1.0
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1835 - accuracy: 0.9440
# 313/313 [==============================] - 1s 4ms/step - loss: 13.6499 - accuracy: 0.1119
# 313/313 [==============================] - 1s 4ms/step - loss: 2.0051 - accuracy: 0.8133
# 313/313 [==============================] - 2s 5ms/step - loss: 2.8041 - accuracy: 0.1042
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1886 - accuracy: 0.9419
# 313/313 [==============================] - 1s 4ms/step - loss: 2.7787 - accuracy: 0.1026
# 313/313 [==============================] - 1s 4ms/step - loss: 1.4305 - accuracy: 0.8100
# 313/313 [==============================] - 1s 4ms/step - loss: 3.2289 - accuracy: 0.1086
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0927 - accuracy: 0.9718
# 313/313 [==============================] - 1s 3ms/step - loss: 2.3119 - accuracy: 0.1042
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1879 - accuracy: 0.9456
# 313/313 [==============================] - 1s 4ms/step - loss: 2.3072 - accuracy: 0.1137
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0862 - accuracy: 0.9716
# 313/313 [==============================] - 1s 3ms/step - loss: 2.3074 - accuracy: 0.1142
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1976 - accuracy: 0.9426
# 313/313 [==============================] - 1s 3ms/step - loss: 2.3041 - accuracy: 0.1009
#
# Normalization sum:  1.0
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
# 313/313 [==============================] - 1s 4ms/step - loss: 0.9799 - accuracy: 0.8440
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1394 - accuracy: 0.9555
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1493 - accuracy: 0.9534
# 313/313 [==============================] - 1s 4ms/step - loss: 3.0500 - accuracy: 0.1090
# 313/313 [==============================] - 1s 4ms/step - loss: 0.8387 - accuracy: 0.8508
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1486 - accuracy: 0.9523
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1461 - accuracy: 0.9558
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1526 - accuracy: 0.9528
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1501 - accuracy: 0.9577
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0783 - accuracy: 0.9756
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0814 - accuracy: 0.9743
# 313/313 [==============================] - 1s 4ms/step - loss: 2.3069 - accuracy: 0.1030
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1564 - accuracy: 0.9536
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0834 - accuracy: 0.9729
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0779 - accuracy: 0.9745
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0807 - accuracy: 0.9743
#
# Normalization sum:  1.0
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
#
# Mutation!
# 313/313 [==============================] - 1s 4ms/step - loss: 1.1991 - accuracy: 0.8712
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2212 - accuracy: 0.9323
# 313/313 [==============================] - 1s 4ms/step - loss: 0.7815 - accuracy: 0.8351
# 313/313 [==============================] - 1s 4ms/step - loss: 2.7602 - accuracy: 0.2748
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2166 - accuracy: 0.9364
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2120 - accuracy: 0.9344
# 313/313 [==============================] - 1s 4ms/step - loss: 21.4911 - accuracy: 0.1364
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2180 - accuracy: 0.9340
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1709 - accuracy: 0.9532
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1070 - accuracy: 0.9687
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1656 - accuracy: 0.9559
# 313/313 [==============================] - 1s 3ms/step - loss: 1.2914 - accuracy: 0.6270
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1218 - accuracy: 0.9632
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1067 - accuracy: 0.9668
# 313/313 [==============================] - 1s 3ms/step - loss: 2.3280 - accuracy: 0.1181
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1065 - accuracy: 0.9681
